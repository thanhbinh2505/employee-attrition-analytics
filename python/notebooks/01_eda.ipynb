# %%
import sys
from pathlib import Path

Duong_Dan_Goc = Path(r"D:\HR Analytics")
sys.path.append(str(Duong_Dan_Goc/"python"/"src"))

import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from db import get_engine

# %%
engine = get_engine()
query="""
select *
from dw.View_ML_NhanVien
order by NgayThang, MaNV
"""
df = pd.read_sql(query, engine)
df.head()
# Out:
#    MaNV   NgayThang   Nam                PhongBan            ChucDanh  \
# 0     5  2018-01-01  2018  Information Technology          IT Support
# 1     6  2018-01-01  2018                   Sales    Sales Supervisor
# 2     7  2018-01-01  2018              Operations  Operations Manager
# 3     8  2018-01-01  2018         Human Resources      C&B Specialist
# 4    10  2018-01-01  2018         Human Resources      C&B Specialist
#
#    CapBacCongViec  Tuoi  KhoangCachTuNha  SoLuongDuAn  SoGioTrungBinhThang  \
# 0               2    41               15            5                  194
# 1               1    29               16            3                  206
# 2               2    28               36            1                  177
# 3               3    35                3            4                  240
# 4               2    38               35            3                  166
#
#    LamThemGio  DiemDanhGiaHieuSuat  DiemHaiLongCongViec  DiemHaiLongMoiTruong  \
# ...

# %%
print("Shape: ", df.shape)
print("Tong Nhan Vien: ", df["MaNV"].nunique())
print("Tong Nghi Viec: ", df["TargetNghiViec"].sum())
print("Nam:", df["Nam"].min(), "-", df["Nam"].max())
# Out:
# Shape:  (39641, 19)
# Tong Nhan Vien:  10000
# Tong Nghi Viec:  6233
# Nam: 2018 - 2025

# %%
df.isna().sum()
# Out:
# MaNV                       0
# NgayThang                  0
# Nam                        0
# PhongBan                   0
# ChucDanh                   0
# CapBacCongViec             0
# Tuoi                       0
# KhoangCachTuNha            0
# SoLuongDuAn                0
# SoGioTrungBinhThang        0
# LamThemGio                 0
# DiemDanhGiaHieuSuat        0
# DiemHaiLongCongViec        0
# DiemHaiLongMoiTruong       0
# ThuNhapThang               0
# SoNamTaiCongTy             0
# SoNamTuLanThangChucCuoi    0
# DuocThangChucNamTruoc      0
# TargetNghiViec             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39641 entries, 0 to 39640
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   MaNV                     39641 non-null  int64
#  1   NgayThang                39641 non-null  object
#  2   Nam                      39641 non-null  int64
#  3   PhongBan                 39641 non-null  str
#  4   ChucDanh                 39641 non-null  str
#  5   CapBacCongViec           39641 non-null  int64
#  6   Tuoi                     39641 non-null  int64
#  7   KhoangCachTuNha          39641 non-null  int64
#  8   SoLuongDuAn              39641 non-null  int64
#  9   SoGioTrungBinhThang      39641 non-null  int64
#  10  LamThemGio               39641 non-null  bool
#  11  DiemDanhGiaHieuSuat      39641 non-null  int64
#  12  DiemHaiLongCongViec      39641 non-null  int64
#  13  DiemHaiLongMoiTruong     39641 non-null  int64
# ...

# %%
df["TargetNghiViec"].value_counts()
# Out:
# TargetNghiViec
# 0    33408
# 1     6233
# Name: count, dtype: int64
